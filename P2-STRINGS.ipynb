# %%
"Hello"
# Out:
# 'Hello'

# %%
print("hello world")
# Out:
# hello world

# %%
name = 'emre'

# %%
print (name)
# Out:
# emre

# %%
type (name)
# Out:
# str

# %%
name.capitalize()
# Out:
# 'Emre'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
name.upper()
# Out:
# 'EMRE'

# %%
x=10

# %%
x.

# %%
len (name)
# Out:
# 4

# %%
print ("emre dandal")
# Out:
# emre dandal

# %%
print ("emre \tdandal")
# Out:
# emre 	dandal

# %%
print ("emre \ndandal")
# Out:
# emre
# dandal

# %%
myString = "hello python"

# %%
myString[11]
# Out:
# 'n'

# %%
myString[1]
# Out:
# 'e'

# %%
myString
# Out:
# 'hello python'

# %%
len(myString) - 1
# Out:
# 11

# %%
barcode = "ABCDE123123982"

# %%
barcode[0]
# Out:
# 'A'

# %%
name = "emre"

# %%
surname = "dandal"

# %%
full_name = name + " " + surname

# %%
full_name
# Out:
# 'emre dandal'

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[::2]
# Out:
# 'ACE2138'
